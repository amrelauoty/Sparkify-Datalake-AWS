# %%
import configparser
import os
from pyspark.sql import SparkSession
from pyspark.sql.functions import year, month

# %%
config = configparser.ConfigParser()
config.read('dl.cfg')
# Out:
# ['dl.cfg']

# %%
os.environ['AWS_ACCESS_KEY_ID']=config['AWS']['AWS_ACCESS_KEY_ID']
os.environ['AWS_SECRET_ACCESS_KEY']=config['AWS']['AWS_SECRET_ACCESS_KEY']

# %%
config['AWS']['AWS_SECRET_ACCESS_KEY']
# Out:
# 'HFN31qN/q6IsCL6g0DXk2+pcpnJ+5Du3rYgjit28'

# %%
spark = SparkSession \
        .builder \
        .appName("spark-datalake") \
        .config("spark.jars.packages", "org.apache.hadoop:hadoop-aws:2.7.0") \
        .getOrCreate()

# %%
input_data = "s3a://udacity-dend/"
output_data ="files/"

# %%
song_data = input_data + 'song_data/A/A/A/*.json' 
song_data
# Out:
# 's3a://udacity-dend/song_data/A/A/A/*.json'

# %%
df = spark.read.json(song_data)

# %%
songs_columns = ['song_id','title','artist_id','year','duration']
songs_table = df.selectExpr(*songs_columns)

# %%
songs_table.toPandas()
# Out:
#                song_id                                              title  \
# 0   SOAFBCP12A8C13CC7D              King Of Scurf (2007 Digital Remaster)
# 1   SOKTJDS12AF72A25E5  Drown In My Own Tears (24-Bit Digitally Remast...
# 2   SOEKAZG12AB018837E      I'll Slap Your Face (Entertainment USA Theme)
# 3   SOQPWCR12A6D4FB2A3                   A Poor Recipe For Civic Cohesion
# 4   SOBRKGM12A8C139EF6                        Welcome to the Pleasuredome
# 5   SORRNOC12AB017F52B                 The Last Beat Of My Heart (b-side)
# 6   SOHKNRJ12A6701D1F8                                       Drop of Rain
# 7   SOAPERH12A58A787DC                          The One And Only (Edited)
# 8   SOSMJFC12A8C13DE0C                              Is That All There Is?
# 9   SOOVHYF12A8C134892                                    I'll Be Waiting
# 10  SOERIDA12A6D4F8506                         I Want You (Album Version)
# 11  SOABWAP12A8C13F82A                                          Take Time
# 12  SOIGHOD12A8C13B5A1                                       Indian Angel
# 13  SONRWUU12AF72A4283                                 Into The Nightlife
# 14  SOCIWDW12A8C13D406                                          Soul Deep
# 15  SOHOZBI12A8C132E3C                                        Smash It Up
# 16  SODZYPO12A8C13A91E                       Burn My Body (Album Version)
# 17  SOFRDWL12A58A7CEF7                                       Hit Da Scene
# 18  SONQPZK12AB0182D84                                        Double Wide
# 19  SOXZYWX12A6310ED0C                                    It's About Time
# 20  SOIGICF12A8C141BC5                                       Game & Watch
# 21  SOBLFFE12AF72AA5BA                                             Scream
# 22  SOFSOCN12A8C143F5D                                     Face the Ashes
# 23  SOTAZDY12AB0187616                                           Drillbit
#
#              artist_id  year   duration
# 0   ARTC1LV1187B9A4858  1972  301.40036
# 1   ARA23XO1187B9AF18F     0  192.52200
# 2   ARSVTNL1187B992A91  2001  129.85424
# 3   AR73AIO1187B9AD57B  2005  118.07302
# 4   ARXQBR11187B98A2CC  1985  821.05424
# 5   ARSZ7L31187FB4E610  2004  337.81506
# 6   AR10USD1187B99F3F1     0  189.57016
# 7   ARZ5H0P1187B98A1DD     0  230.42567
# 8   AR1KTV21187B9ACD72     0  343.87546
# 9   ARCLYBR1187FB53913  1989  304.56118
# 10  ARBZIN01187FB362CC  2006  192.28689
# 11  AR5LMPY1187FB573FE  1978  258.89914
# 12  ARY589G1187B9A9F4E  2004  171.57179
# 13  ARGE7G11187FB37E05  2008  240.63955
# 14  ARMJAGH1187FB546F3  1969  148.03546
# 15  AR0MWD61187B9B2B12  2000  195.39546
# 16  AR1C2IX1187B99BF74     0  177.99791
# 17  AR9Q9YC1187FB5609B     0  252.94322
# 18  ARKYKXP11F50C47A6A     0  160.20853
# 19  ARC1IHZ1187FB4E920     0  246.98730
# 20  AREWD471187FB49873  2004  580.54485
# 21  ARJNIUY12298900C91  2009  213.94240
# 22  ARXR32B1187FB57099  2007  209.60608
# 23  ARZKCQM1257509D107     0  374.62159

# %%
songs_table.write.partitionBy(['year','artist_id']).parquet("{}/songs.parquet".format(output_data),mode="overwrite")

# %%
artists_columns = ['artist_id','artist_name as name','artist_location as location','artist_latitude as latitude','artist_longitude as longitude']
artists_table = df.selectExpr(*artists_columns)
artists_table.createOrReplaceTempView('artists')

# %%
spark.sql("select artist_id, \
                  name, \
                  case \
                      when trim(location) = '' \
                      then Null \
                      else location \
                      end as location, \
                  latitude,longitude \
                  from artists").toPandas()
# Out:
#              artist_id                            name  \
# 0   ARTC1LV1187B9A4858              The Bonzo Dog Band
# 1   ARA23XO1187B9AF18F                 The Smithereens
# 2   ARSVTNL1187B992A91                   Jonathan King
# 3   AR73AIO1187B9AD57B               Western Addiction
# 4   ARXQBR11187B98A2CC       Frankie Goes To Hollywood
# 5   ARSZ7L31187FB4E610                       Devotchka
# 6   AR10USD1187B99F3F1           Tweeterfriendly Music
# 7   ARZ5H0P1187B98A1DD                      Snoop Dogg
# 8   AR1KTV21187B9ACD72                        Cristina
# 9   ARCLYBR1187FB53913                      Neal Schon
# 10  ARBZIN01187FB362CC                    Paris Hilton
# 11  AR5LMPY1187FB573FE               Chaka Khan_ Rufus
# 12  ARY589G1187B9A9F4E                     Talkdemonic
# 13  ARGE7G11187FB37E05                    Cyndi Lauper
# 14  ARMJAGH1187FB546F3                    The Box Tops
# 15  AR0MWD61187B9B2B12  International Noise Conspiracy
# 16  AR1C2IX1187B99BF74                 Broken Spindles
# 17  AR9Q9YC1187FB5609B                Quest_ Pup_ Kevo
# 18  ARKYKXP11F50C47A6A                The Supersuckers
# 19  ARC1IHZ1187FB4E920                    Jamie Cullum
# 20  AREWD471187FB49873                        Son Kite
# 21  ARJNIUY12298900C91                    Adelitas Way
# 22  ARXR32B1187FB57099                             Gob
# 23  ARZKCQM1257509D107                      Dataphiles
#
#                              location  latitude  longitude
# 0   Goldsmith's College, Lewisham, Lo  51.45360   -0.01802
# 1                Carteret, New Jersey  40.57885  -74.21956
# 2                     London, England  51.50632   -0.12714
# 3                   San Francisco, CA  37.77916 -122.42005
# 4                  Liverpool, England       NaN        NaN
# 5                          Denver, CO  39.74001 -104.99226
# 6         Burlington, Ontario, Canada       NaN        NaN
# 7                      Long Beach, CA  33.76672 -118.19240
# 8                     California - LA  34.05349 -118.24532
# 9                       San Mateo, CA  37.54703 -122.31483
# 10                                 27   1.32026  103.78871
# 11                        Chicago, IL  41.88415  -87.63241
# 12                       Portland, OR  45.51179 -122.67563
# 13                       Brooklyn, NY       NaN        NaN
# 14                        Memphis, TN  35.14968  -90.04892
# 15                               None       NaN        NaN
# 16                               None       NaN        NaN
# 17                         New Jersey       NaN        NaN
# 18                               None       NaN        NaN
# 19                               None       NaN        NaN
# 20                               None       NaN        NaN
# 21                               None       NaN        NaN
# 22                               None       NaN        NaN
# 23                               None       NaN        NaN

# %%
artists_table = spark.sql("select artist_id, \
                  name, \
                  case \
                      when trim(location) = '' \
                      then Null \
                      else location \
                      end as location, \
                  latitude,longitude \
                  from artists")

# %%
artists_table.write.parquet("{}/artists.parquet".format(output_data),mode="overwrite")

# %%
log_data = input_data+'log_data/2018/11/*.json'

# %%
df = spark.read.json(log_data)

# %%
df = df.filter(df.page =='NextSong')

# %%
users_columns = ['userId as user_id','firstName as first_name','lastName as last_name','gender','level']
users_table = df.selectExpr(*users_columns).distinct()

# %%
users_table.toPandas().head(10)
# Out:
#   user_id first_name  last_name gender level
# 0      26       Ryan      Smith      M  free
# 1       7     Adelyn     Jordan      F  free
# 2      71     Ayleen       Wise      F  free
# 3      81     Sienna      Colon      F  free
# 4      87     Dustin        Lee      M  free
# 5      23     Morris    Gilmore      M  free
# 6      75     Joseph  Gutierrez      M  free
# 7      16      Rylan     George      M  paid
# 8       2    Jizelle   Benjamin      F  free
# 9       3      Isaac     Valdez      M  free

# %%
users_table.write.parquet('{}/users.parquet'.format(output_data),mode="overwrite")

# %%
df.createOrReplaceTempView("user_logs")

time_table = spark.sql("select \
                        t.timestamp as start_time, \
                        hour(t.timestamp)       as hour, \
                        day(t.timestamp)        as day, \
                        weekofyear(t.timestamp) as week, \
                        month(t.timestamp)      as month, \
                        year(t.timestamp)       as year, \
                        dayofweek(t.timestamp)  as weekday \
                        from \
                        (select from_unixtime(ts/1000) as timestamp from user_logs group by timestamp) as t"
                        )

# %%
time_table.toPandas().head(10)
# Out:
#             start_time  hour  day  week  month  year  weekday
# 0  2018-11-15 07:56:18     7   15    46     11  2018        5
# 1  2018-11-15 16:51:56    16   15    46     11  2018        5
# 2  2018-11-15 18:31:38    18   15    46     11  2018        5
# 3  2018-11-14 00:41:15     0   14    46     11  2018        4
# 4  2018-11-14 00:53:43     0   14    46     11  2018        4
# 5  2018-11-14 17:30:51    17   14    46     11  2018        4
# 6  2018-11-14 22:40:13    22   14    46     11  2018        4
# 7  2018-11-05 09:44:49     9    5    45     11  2018        2
# 8  2018-11-05 14:52:12    14    5    45     11  2018        2
# 9  2018-11-05 15:19:50    15    5    45     11  2018        2

# %%
time_table.write.partitionBy(['year','month']).parquet("{}/time.parquet".format(output_data),mode="overwrite")

# %%
song_df = spark.read.parquet("{}/song.parquet".format(output_data))

song_df.createOrReplaceTempView("songs")

# %%
spark.sql("select * from user_logs Limit 10").toPandas()
# Out:
#                                artist       auth firstName gender  \
# 0                            Harmonia  Logged In      Ryan      M
# 1                         The Prodigy  Logged In      Ryan      M
# 2                               Train  Logged In      Ryan      M
# 3                         Sony Wonder  Logged In    Samuel      M
# 4                           Van Halen  Logged In     Tegan      F
# 5                           Magic Sam  Logged In     Tegan      F
# 6  Edward Sharpe & The Magnetic Zeros  Logged In     Tegan      F
# 7           Usher featuring will.i.am  Logged In     Tegan      F
# 8                         Helen Reddy  Logged In     Tegan      F
# 9                        Taylor Swift  Logged In     Tegan      F
#
#    itemInSession  lastName     length level  \
# 0              0     Smith  655.77751  free
# 1              1     Smith  260.07465  free
# 2              2     Smith  205.45261  free
# 3              0  Gonzalez  218.06975  free
# 4              2    Levine  289.38404  paid
# 5              3    Levine  132.04853  paid
# 6              4    Levine  306.31138  paid
# 7              5    Levine  395.72853  paid
# 8              7    Levine  176.50893  paid
# 9              8    Levine  201.06404  paid
#
#                                location method      page  registration  \
# 0    San Jose-Sunnyvale-Santa Clara, CA    PUT  NextSong  1.541017e+12
# 1    San Jose-Sunnyvale-Santa Clara, CA    PUT  NextSong  1.541017e+12
# 2    San Jose-Sunnyvale-Santa Clara, CA    PUT  NextSong  1.541017e+12
# 3  Houston-The Woodlands-Sugar Land, TX    PUT  NextSong  1.540493e+12
# 4           Portland-South Portland, ME    PUT  NextSong  1.540794e+12
# 5           Portland-South Portland, ME    PUT  NextSong  1.540794e+12
# 6           Portland-South Portland, ME    PUT  NextSong  1.540794e+12
# 7           Portland-South Portland, ME    PUT  NextSong  1.540794e+12
# 8           Portland-South Portland, ME    PUT  NextSong  1.540794e+12
# 9           Portland-South Portland, ME    PUT  NextSong  1.540794e+12
#
#    sessionId                                            song  status  \
# 0        583                                   Sehr kosmisch     200
# 1        583                                 The Big Gundown     200
# 2        583                                        Marry Me     200
# 3        597                                       Blackbird     200
# 4        602  Best Of Both Worlds (Remastered Album Version)     200
# 5        602                          Call Me If You Need Me     200
# 6        602                                            Home     200
# 7        602                                             OMG     200
# 8        602                             Candle On The Water     200
# 9        602                                        Our Song     200
#
#               ts                                          userAgent userId
# 0  1542241826796  "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...     26
# 1  1542242481796  "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...     26
# 2  1542242741796  "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...     26
# 3  1542253449796  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...     61
# 4  1542260935796  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...     80
# 5  1542261224796  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...     80
# 6  1542261356796  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...     80
# 7  1542261662796  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...     80
# 8  1542262057796  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...     80
# 9  1542262233796  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...     80

# %%
spark.sql("select * from songs LIMIT 10").toPandas()
# Out:
#               song_id                                              title  \
# 0  SOKTJDS12AF72A25E5  Drown In My Own Tears (24-Bit Digitally Remast...
# 1  SOEKAZG12AB018837E      I'll Slap Your Face (Entertainment USA Theme)
# 2  SOAFBCP12A8C13CC7D              King Of Scurf (2007 Digital Remaster)
# 3  SORRNOC12AB017F52B                 The Last Beat Of My Heart (b-side)
# 4  SOQPWCR12A6D4FB2A3                   A Poor Recipe For Civic Cohesion
# 5  SODZYPO12A8C13A91E                       Burn My Body (Album Version)
# 6  SOBRKGM12A8C139EF6                        Welcome to the Pleasuredome
# 7  SOERIDA12A6D4F8506                         I Want You (Album Version)
# 8  SOAPERH12A58A787DC                          The One And Only (Edited)
# 9  SOSMJFC12A8C13DE0C                              Is That All There Is?
#
#     duration  year           artist_id
# 0  192.52200     0  ARA23XO1187B9AF18F
# 1  129.85424  2001  ARSVTNL1187B992A91
# 2  301.40036  1972  ARTC1LV1187B9A4858
# 3  337.81506  2004  ARSZ7L31187FB4E610
# 4  118.07302  2005  AR73AIO1187B9AD57B
# 5  177.99791     0  AR1C2IX1187B99BF74
# 6  821.05424  1985  ARXQBR11187B98A2CC
# 7  192.28689  2006  ARBZIN01187FB362CC
# 8  230.42567     0  ARZ5H0P1187B98A1DD
# 9  343.87546     0  AR1KTV21187B9ACD72

# %%
songplays_table = spark.sql("select \
                             monotonically_increasing_id() as songplay_id, \
                             from_unixtime(user_logs.ts/1000) as start_time, \
                             user_logs.userId as user_id, \
                             user_logs.level as level,\
                             songs.song_id as song_id, \
                             songs.artist_id as artist_id, \
                             user_logs.sessionId as session_id, \
                             user_logs.location, \
                             user_logs.userAgent as user_agent\
                             from \
                             user_logs \
                             left join songs \
                             on user_logs.song = songs.title"
                             )

# %%
songplays_table.toPandas().head(10)
# Out:
#    songplay_id           start_time user_id level song_id artist_id  \
# 0            0  2018-11-15 00:30:26      26  free    None      None
# 1            1  2018-11-15 00:41:21      26  free    None      None
# 2            2  2018-11-15 00:45:41      26  free    None      None
# 3            3  2018-11-15 03:44:09      61  free    None      None
# 4            4  2018-11-15 05:48:55      80  paid    None      None
# 5            5  2018-11-15 05:53:44      80  paid    None      None
# 6            6  2018-11-15 05:55:56      80  paid    None      None
# 7            7  2018-11-15 06:01:02      80  paid    None      None
# 8            8  2018-11-15 06:07:37      80  paid    None      None
# 9            9  2018-11-15 06:10:33      80  paid    None      None
#
#    session_id                              location  \
# 0         583    San Jose-Sunnyvale-Santa Clara, CA
# 1         583    San Jose-Sunnyvale-Santa Clara, CA
# 2         583    San Jose-Sunnyvale-Santa Clara, CA
# 3         597  Houston-The Woodlands-Sugar Land, TX
# 4         602           Portland-South Portland, ME
# 5         602           Portland-South Portland, ME
# 6         602           Portland-South Portland, ME
# 7         602           Portland-South Portland, ME
# 8         602           Portland-South Portland, ME
# 9         602           Portland-South Portland, ME
#
#                                           user_agent
# 0  "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...
# 1  "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...
# 2  "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...
# 3  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...
# 4  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...
# 5  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...
# 6  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...
# 7  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...
# 8  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...
# 9  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...

# %%
songplays_table = songplays_table.withColumn('year',year(songplays_table.start_time)).withColumn('month',month(songplays_table.start_time))

# %%
songplays_table.write.partitionBy(['year','month']).parquet("{}/songplays.parquet".format(output_data),mode="overwrite")

# %%
songplays_df = spark.read.parquet("{}/songplays.parquet".format(output_data))

# %%
songplays_df.toPandas().head(10)
# Out:
#    songplay_id           start_time user_id level song_id artist_id  \
# 0            0  2018-11-15 00:30:26      26  free    None      None
# 1            1  2018-11-15 00:41:21      26  free    None      None
# 2            2  2018-11-15 00:45:41      26  free    None      None
# 3            3  2018-11-15 03:44:09      61  free    None      None
# 4            4  2018-11-15 05:48:55      80  paid    None      None
# 5            5  2018-11-15 05:53:44      80  paid    None      None
# 6            6  2018-11-15 05:55:56      80  paid    None      None
# 7            7  2018-11-15 06:01:02      80  paid    None      None
# 8            8  2018-11-15 06:07:37      80  paid    None      None
# 9            9  2018-11-15 06:10:33      80  paid    None      None
#
#    session_id                              location  \
# 0         583    San Jose-Sunnyvale-Santa Clara, CA
# 1         583    San Jose-Sunnyvale-Santa Clara, CA
# 2         583    San Jose-Sunnyvale-Santa Clara, CA
# 3         597  Houston-The Woodlands-Sugar Land, TX
# 4         602           Portland-South Portland, ME
# 5         602           Portland-South Portland, ME
# 6         602           Portland-South Portland, ME
# 7         602           Portland-South Portland, ME
# 8         602           Portland-South Portland, ME
# 9         602           Portland-South Portland, ME
#
#                                           user_agent  year  month
# 0  "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...  2018     11
# 1  "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...  2018     11
# 2  "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...  2018     11
# 3  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...  2018     11
# 4  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...  2018     11
# 5  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...  2018     11
# 6  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...  2018     11
# 7  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...  2018     11
# 8  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...  2018     11
# 9  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...  2018     11
